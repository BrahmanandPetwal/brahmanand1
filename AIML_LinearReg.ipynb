# %% [markdown]
# <a href="https://colab.research.google.com/github/Mythicalsaga/brahmanand1/blob/main/AIML_LinearReg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# !cp "/content/drive/MyDrive/Salary_Data.csv" "/content/sample_data"

# %%
df = pd.read_csv("/content/sample_data/Salary_Data.csv")

# %%
df.shape
# Out:
# (30, 2)

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
plt.scatter(df["YearsExperience"],df["Salary"])
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.show()

# %%
X = df.iloc[:,0:1]
Y = df.iloc[:,-1]

# %%
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
Y
# Out:
# 0      39343
# 1      46205
# 2      37731
# 3      43525
# 4      39891
# 5      56642
# 6      60150
# 7      54445
# 8      64445
# 9      57189
# 10     63218
# 11     55794
# 12     56957
# 13     57081
# 14     61111
# 15     67938
# 16     66029
# 17     83088
# 18     81363
# 19     93940
# 20     91738
# 21     98273
# 22    101302
# 23    113812
# 24    109431
# 25    105582
# 26    116969
# 27    112635
# 28    122391
# 29    121872
# Name: Salary, dtype: int64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size= 0.3, random_state= 3)

# %%
lr = LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_predicted = lr.predict(X_test)
print(y_predicted)
# Out:
# [ 73289.5314978   54692.70041028 101184.77812906 116062.24299907
#   82587.94704155  69570.16528029  65850.79906279  41674.91864903
#   75149.21460655]

# %%
plt.scatter(df["YearsExperience"],df["Salary"])
plt.plot(X_train,lr.predict(X_train),color="red")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.show()
